# %%
import pandas as pd

# %%
economics = pd.read_csv("C:\\Users\\carol\\Documents_Local\\AECN_Capstone\\AECN\\UScensus_data\\edited_datasheets\\Economic_Characteristics_edit.csv", index_col=0)
families = pd.read_csv("C:\\Users\\carol\\Documents_Local\\AECN_Capstone\\AECN\\UScensus_data\\edited_datasheets\\Households_&Families_edit.csv", index_col=0)
population = pd.read_csv("C:\\Users\\carol\\Documents_Local\\AECN_Capstone\\AECN\\UScensus_data\\edited_datasheets\\Age_&Sex_edit.csv", index_col=0)
earners = pd.read_csv("C:\\Users\\carol\\Documents_Local\\AECN_Capstone\\AECN\\UScensus_data\\edited_datasheets\\Median_Income_edit.csv", index_col=0)

# %% [markdown]
# imported pandas and created dataframes from the US census csv files
# Next, use .drop() to remove rows/columns

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(earners)
# Out:
#                                    Bath County, Kentucky!!Number!!Estimate  \
# Label (Grouping)
# FAMILY INCOME BY NUMBER OF EARNERS                                     NaN
#     No earners                                                         769
#     1 earner                                                         1,080
#     2 earners                                                        1,279
#     3 or more earners                                                  251
#
#                                    Bath County, Kentucky!!Percent Distribution!!Estimate  \
# Label (Grouping)
# FAMILY INCOME BY NUMBER OF EARNERS                                                NaN
#     No earners                                                                 22.80%
#     1 earner                                                                   32.00%
#     2 earners                                                                  37.90%
# ...

# %%
#earners.reset_index()
earners.head()
# Out:
#                                    Bath County, Kentucky!!Number!!Estimate  \
# Label (Grouping)
# FAMILY INCOME BY NUMBER OF EARNERS                                     NaN
#     No earners                                                         769
#     1 earner                                                         1,080
#     2 earners                                                        1,279
#     3 or more earners                                                  251
#
#                                    Bath County, Kentucky!!Percent Distribution!!Estimate  \
# Label (Grouping)
# FAMILY INCOME BY NUMBER OF EARNERS                                                NaN
#     No earners                                                                 22.80%
#     1 earner                                                                   32.00%
#     2 earners                                                                  37.90%
# ...

# %%
earners_df = earners.drop(columns=["BathCounty,Kentucky!!Number!!Estimate","Bath County,Kentucky!!PercentDistribution!!Estimate"])

#Bath County, Kentucky!!Number!!Estimate	Bath County, Kentucky!!Percent Distribution!!Estimate
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 earners_df = earners.drop(columns=["BathCounty,Kentucky!!Number!!Estimate","Bath County,Kentucky!!PercentDistribution!!Estimate"])
#       3 #Bath County, Kentucky!!Number!!Estimate	Bath County, Kentucky!!Percent Distribution!!Estimate
#
# File c:\Users\carol\python\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
# ...
