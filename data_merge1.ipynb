# %%
import pandas as pd

# %%
#commute = pd.read_csv("C:\\Users\\carol\\Documents_Local\\AECN_Capstone\\AECN\\UScensus_data\\edited_datasheets\\Narrowed_datasheets\\commute_time.csv", index_col=0)
#families = pd.read_csv("C:\\Users\\carol\\Documents_Local\\AECN_Capstone\\AECN\\UScensus_data\\edited_datasheets\\Narrowed_datasheets\\families1.csv", index_col=0)
#percapita_income = pd.read_csv("C:\\Users\\carol\Documents_Local\\AECN_Capstone\\AECN\\UScensus_data\\edited_datasheets\\Narrowed_datasheets\\PerCapitaIncome.csv", index_col=0)
#children_age = pd.read_csv("C:\\Users\\carol\\Documents_Local\\AECN_Capstone\\AECN\\UScensus_data\\edited_datasheets\\Narrowed_datasheets\\family_children_age.csv", index_col=0)

# %% [markdown]
# use relative path, not absolute path. (Sought relative path through gitbash using $ git rev-parse --show-prefix)
# remove double backstrokes

# %%
#commute = pd.read_csv("UScensus_data\\edited_datasheets\\Narrowed_datasheets\\commute_time.csv", index_col=0)
    #No such file or directory
#commute = pd.read_csv("UScensus_data\edited_datasheets\Narrowed_datasheets\commute_time.csv", index_col=0)
    #Cell In[7],   line 2
    #commute = pd.read_csv("UScensus_data\edited_datasheets\Narrowed_datasheets\commute_time.csv", index_col=0)
#                          ^
#SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 31-32: malformed \N character escape

#commute = pd.read_csv("UScensus_data/edited_datasheets/Narrowed_datasheets/commute_time.csv", index_col=0)
    #No such file or directory.

# %% [markdown]
# So far, not good. I'm struggling with something as basic as reading in a csv file.
# Was able to open the file in vs code and right-click to get the relative path, but it's still not working.

# %%
#commute = pd.read_csv("..AECN_Capstone\AECN\UScensus_data\edited_datasheets\Narrowed_datasheets\commute_time.csv", index_col=0)
#        Cell In[34],   line 1
#   commute = pd.read_csv("..AECN_Capstone\AECN\UScensus_data\edited_datasheets\Narrowed_datasheets\commute_time.csv", index_col=0)
#                          ^
#SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 20-21: truncated \UXXXXXXXX escape
#
#commute = pd.read_csv("AECN_Capstone/AECN/UScensus_data/edited_datasheets/Narrowed_datasheets/commute_time.csv")
#FileNotFoundError

commute = pd.read_csv("C:\\Users\\carol\\Documents_Local\\AECN_Capstone\\AECN\\UScensus_data\\edited_datasheets\\Narrowed_datasheets\\commute_time.csv", index_col=0)

# %% [markdown]
# Great. Using the absolute path with double brackets works to read in the csv file, but now nobody else but me can read in the file. Wonderful.

# %%
#percapitaincome = pd.read_csv("C:\Users\carol\Documents_Local\AECN_Capstone\AECN\UScensus_data\edited_datasheets\Narrowed_datasheets\PerCapitaIncome.csv", index_col=0)
#opened PerCapitaIncome.csv in vs code and right-clicked to copy the relative path into the "". Got a syntaxerror aimed at the first " ?? Also, not sure how starting from C:\ equates to a relative path.
#added double brackets and now all of a sudden the code works. syntaxerror mysteriously resolved. Lovely.
percapitaincome = pd.read_csv("C:\\Users\\carol\\Documents_Local\\AECN_Capstone\\AECN\\UScensus_data\\edited_datasheets\\Narrowed_datasheets\\PerCapitaIncome.csv", index_col=0)

# %%
families = pd.read_csv("C:\\Users\\carol\\Documents_Local\\AECN_Capstone\\AECN\\UScensus_data\\edited_datasheets\\Narrowed_datasheets\\families1.csv", index_col=0)
children_age = pd.read_csv("C:\\Users\\carol\\Documents_Local\\AECN_Capstone\\AECN\\UScensus_data\\edited_datasheets\\Narrowed_datasheets\\family_children_age.csv", index_col=0)

# %% [markdown]
# re-saved all the files as *utf-8* csv files. Was able to read them in successfully (with supposedly the relative path as copied from vs code). Only worked with double brackets.

# %%
#commute.head()
#percapitaincome.head()
#families.head()
#children_age.head()

# %% [markdown]
# now Im going to concat them all together becuase what the hell why not. At least I think I am. We'll see what happens.

# %%
#eastern_mountian_region = pd.concat([commute, percapitaincome, families, children_age])
#Will remove children_age becuase it's all percentages, and I'm worried about how it might affect my ability to manipulate and vizualize the data frame
#First im gonna take a look at what I made with .head() and .shape

# %%
#eastern_mountian_region.head()
# Out:
#                                           Bath County  Boyd County  \
# Mean Travel Time to Work in Minutes              31.3         22.3
#     Per Capita Income                     $27,018.00   $30,993.00
#     Total Families                              3,379       12,022
# Age of Own Children in Family Households          NaN          NaN
#         Under 6 years only                      9.90%       24.10%
#
#                                          Bracken County Breathitt County  \
# Mean Travel Time to Work in Minutes                35.7             28.8
#     Per Capita Income                       $29,164.00       $21,985.00
#     Total Families                                2,227            3,582
# Age of Own Children in Family Households            NaN              NaN
#         Under 6 years only                        9.40%           23.80%
#
#                                          Carter County Elliott County  \
# ...

# %%
#eastern_mountian_region.shape
# Out:
# (6, 28)

# %%
eastern_county_overview = pd.concat([commute, percapitaincome, families])

summary = eastern_county_overview.describe()
print(summary)
# Out:
#         Bath County  Boyd County  Bracken County  Breathitt County  \
# count           3.0          3.0             3.0               3.0
# unique          3.0          3.0             3.0               3.0
# top            31.3         22.3            35.7              28.8
# freq            1.0          1.0             1.0               1.0
#
#         Carter County  Elliott County  Fleming County  Floyd County  \
# count             3.0             3.0             3.0           3.0
# unique            3.0             3.0             3.0           3.0
# top              27.7            42.6            33.3          24.9
# freq              1.0             1.0             1.0           1.0
#
#         Greenup County  Johnson County  ...  Mason County  Menifee County  \
# count              3.0             3.0  ...           3.0             3.0
# unique             3.0             3.0  ...           3.0             3.0
# ...

# %% [markdown]
# I don't know if the .describe() function does anything useful for this dataframe...

# %%
eastern_county_overview.head()
# Out:
#                                      Bath County  Boyd County Bracken County  \
# Mean Travel Time to Work in Minutes         31.3         22.3           35.7
#     Per Capita Income                $27,018.00   $30,993.00     $29,164.00
#     Total Families                         3,379       12,022          2,227
#
#                                     Breathitt County Carter County  \
# Mean Travel Time to Work in Minutes             28.8          27.7
#     Per Capita Income                    $21,985.00    $24,949.00
#     Total Families                             3,582         6,652
#
#                                     Elliott County Fleming County  \
# Mean Travel Time to Work in Minutes           42.6           33.3
#     Per Capita Income                  $17,242.00     $26,230.00
#     Total Families                           1,524          3,997
#
#                                     Floyd County Greenup County  \
# ...

# %% [markdown]
# Okay, Now I want to save this dataframe (eastern_county_overview) as its own csv file and put it in the AECN_datasheets repo folder.

# %%
eastern_county_overview.to_csv("..AECN_Capstone\\AECN\\AECN_datasheets")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 eastern_county_overview.to_csv("..AECN_Capstone\\AECN\\AECN_datasheets")
#
# File c:\Users\carol\python\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...
